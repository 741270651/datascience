# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

# %%
pd.set_option('max_columns', 50)
mpl.rcParams['lines.linewidth'] = 2

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
sns.set(style='ticks',font='simhei',font_scale=1.2)

# %%
iris = sns.load_dataset('iris')

# %%
data = pd.read_excel('D:/VINSON/right-up-corner/BD meeting/plot.xlsx', sheet_name='plot_data')

# %%
data = data.set_index('大区')

# %%
data.head()
# Out:
#         201707    201708    201709    201710    201711    201712    201801  \
# 大区
# 安徽    0.004950  0.094527  0.738916  0.857143  0.852174  0.863636  0.860870
# 北京天津  0.032120  0.274678  0.390086  0.387446  0.399563  0.335366  0.663717
# 福建    0.042460  0.282738  0.451420  0.497015  0.545145  0.583082  0.573333
# 广西贵州  0.209877  0.529621  0.818832  0.840491  0.843329  0.812362  0.837267
# 湖北    0.069825  0.247978  0.601078  0.670330  0.672269  0.637838  0.690217
#
#         201802    201803    201804    201805    201806
# 大区
# 安徽    0.873362  0.886463  0.881057  0.885965  0.889908
# 北京天津  0.731377  0.742925  0.742009  0.742529  0.753521
# 福建    0.592814  0.601757  0.614138  0.619259  0.619259
# 广西贵州  0.821473  0.824373  0.828699  0.833156  0.830803
# 湖北    0.683924  0.686649  0.690608  0.681319  0.677778

# %%
data = data.sort_values(by=data.columns[-1])

# %%
nation = pd.read_excel('D:/VINSON/right-up-corner/BD meeting/plot.xlsx', sheet_name='nation')

# %%
nation
# Out:
#    大区    201707    201708    201709    201710    201711    201712    201801  \
# 0  全国  0.188703  0.468014  0.695525  0.732206  0.756057  0.751524  0.774851
#
#      201802    201803    201804    201805    201806
# 0  0.793717  0.805413  0.811162  0.814222  0.811926

# %%
nation = nation.set_index('大区')

# %%
data = pd.concat([data, nation])

# %%
plt.figure(figsize=(12, 12))

plt.title('SPM WTN Fresh distribution variation over 201707-201806')

sns.heatmap(data, annot=True, fmt='.0%',center=0.0, cmap="PiYG");
