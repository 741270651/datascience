# %%
import tushare as ts

# %%
df = ts.realtime_boxoffice()

# %%
df
# Out:
#    BoxOffice Irank    MovieName boxPer movieDay sumBoxOffice  \
# 0   25159.00     1  复仇者联盟3：无限战争  97.45        1     31076.98
# 1     290.90     2         我是你妈   1.13        1       371.58
# 2     157.25     3        后来的我们   0.61       14    129437.19
# 3     107.85     4        战犬瑞克斯   0.42        1       108.42
# 4      27.56     5         幕后玩家   0.11       14     34486.64
# 5      17.42     6        青年马克思   0.07        7       188.41
# 6      11.64     7         狂暴巨兽   0.05       29     97714.90
# 7       9.79     8    巴霍巴利王2：终结   0.04        8      6884.55
# 8       7.98     9      厉害了，我的国   0.03       71     47790.12
# 9       4.01    10         七号公馆   0.02       -6         4.14
# 10     23.31    11           其它   1.00        0         0.00
#
#                    time
# 0   2018-05-11 12:42:28
# 1   2018-05-11 12:42:28
# 2   2018-05-11 12:42:28
# 3   2018-05-11 12:42:28
# 4   2018-05-11 12:42:28
# 5   2018-05-11 12:42:28
# 6   2018-05-11 12:42:28
# 7   2018-05-11 12:42:28
# ...
